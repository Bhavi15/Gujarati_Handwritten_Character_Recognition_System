# %%
import os
import numpy as np

import numpy as np
import shutil
import random
root_dir = 'Gujarati Characters Dataset Photos/28x28/' # data root path
classes_dir = ['char_0','char_1','char_2','char_3','char_4','char_5','char_6','char_7','char_8','char_9', 'char_10_અ', 'char_11_આ', 'char_12_ઇ', 'char_13_ઈ',
        'char_14_ઉ', 'char_15_ઊ', 'char_16_ઋ','char_17_એ', 'char_18_ઐ','char_19_ઓ','char_20_ઔ', 'char_21_અં', 'char_22_અઃ',
               'char_23_ક', 'char_24_કા', 'char_25_કિ', 'char_26_કી', 'char_27_કુ',
        'char_28_કૂ','char_29_કે','char_30_કૈ', 'char_31_કો', 'char_32_કૌ','char_33_કં','char_34_કઃ','char_35_ખ', 'char_36_ખા', 'char_37_ખિ',
        'char_38_ખી', 'char_39_ખુ', 'char_40_ખૂ', 'char_41_ખે','char_42_ખૈ', 'char_43_ખો', 'char_44_ખૌ','char_45_ખં', 'char_46_ખઃ',
        'char_47_ગ', 'char_48_ગા', 'char_49_ગિ', 'char_50_ગી', 'char_51_ગુ', 'char_52_ગૂ', 'char_53_ગે', 'char_54_ગૈ', 'char_55_ગો',
        'char_56_ગૌ', 'char_57_ગં', 'char_58_ગઃ', 'char_59_ઘ', 'char_60_ઘા', 'char_61_ઘિ','char_62_ઘી', 'char_63_ઘુ', 'char_64_ઘૂ',
        'char_65_ઘે', 'char_66_ઘૈ', 'char_67_ઘો', 'char_68_ઘૌ', 'char_69_ઘં', 'char_70_ઘઃ','char_71_ચ', 'char_72_ચા', 'char_73_ચિ',
        'char_74_ચી', 'char_75_ચુ', 'char_76_ચૂ', 'char_77_ચે', 'char_78_ચૈ', 'char_79_ચો', 'char_80_ચૌ', 'char_81_ચં', 'char_82_ચઃ',
        'char_83_છ', 'char_84_છા', 'char_85_છિ','char_86_છી', 'char_87_છુ','char_88_છૂ', 'char_89_છે','char_90_છૈ','char_91_છો',
        'char_92_છૌ', 'char_93_છં', 'char_94_છઃ', 'char_95_જ', 'char_96_જા', 'char_97_જિ','char_98_જી', 'char_99_જુ','char_100_જૂ',
        'char_101_જે', 'char_102_જૈ', 'char_103_જો', 'char_104_જૌ', 'char_105_જં', 'char_106_જઃ', 'char_107_ઝ', 'char_108_ઝા',
        'char_109_ઝિ','char_110_ઝી', 'char_111_ઝુ','char_112_ઝૂ','char_113_ઝે','char_114_ઝૈ','char_115_ઝો', 'char_116_ઝૌ','char_117_ઝં',
        'char_118_ઝઃ', 'char_119_ટ', 'char_120_ટા', 'char_121_ટિ',
        'char_122_ટી', 'char_123_ટુ', 'char_124_ટૂ', 'char_125_ટે', 'char_126_ટૈ', 'char_127_ટો','char_128_ટૌ', 'char_129_ટં', 
        'char_130_ટઃ', 'char_131_ઠ', 'char_132_ઠા', 'char_133_ઠિ', 'char_134_ઠી','char_135_ઠુ', 'char_136_ઠૂ', 'char_137_ઠે', 
        'char_138_ઠૈ', 'char_139_ઠો', 'char_140_ઠૌ', 'char_141_ઠં', 'char_142_ઠઃ', 'char_143_ડ', 'char_144_ડા', 'char_145_ડિ',
        'char_146_ડી', 'char_147_ડુ','char_148_ડૂ', 'char_149_ડે', 'char_150_ડૈ', 'char_151_ડો', 'char_152_ડૌ', 'char_153_ડં',
        'char_154_ડઃ', 'char_155_ઢ', 'char_156_ઢા', 'char_157_ઢિ', 'char_158_ઢી', 'char_159_ઢુ', 'char_160_ઢૂ',
        'char_161_ઢે', 'char_162_ઢૈ', 'char_163_ઢો', 'char_164_ઢૌ', 'char_165_ઢં', 'char_166_ઢઃ', 'char_167_ણ', 'char_168_ણા',
        'char_169_ણિ', 'char_170_ણી', 'char_171_ણુ','char_172_ણૂ','char_173_ણે', 'char_174_ણૈ','char_175_ણો', 'char_176_ણૌ',
        'char_177_ણં', 'char_178_ણઃ', 'char_179_ત', 'char_180_તા', 'char_181_તિ', 'char_182_તી', 'char_183_તુ', 'char_184_તૂ',
        'char_185_તે', 'char_186_તૈ', 'char_187_તો', 'char_188_તૌ', 'char_189_થ','char_190_થા', 'char_191_થિ', 'char_192_થી',
        'char_193_થુ', 'char_194_થૂ', 'char_195_થે','char_196_થૈ', 'char_197_થો','char_198_થૌ','char_199_થં', 'char_200_થઃ', 
        'char_201_દ', 'char_202_દા','char_203_દિ', 'char_204_દી', 'char_205_દુ', 'char_206_દૂ', 'char_207_દે', 'char_208_દૈ',
        'char_209_દો', 'char_210_દૌ','char_211_દં', 'char_212_દઃ', 'char_213_ધ', 'char_214_ધા', 'char_215_ધિ', 'char_216_ધી',
        'char_217_ધુ', 'char_218_ધૂ', 'char_219_ધે', 'char_220_ધૈ', 'char_221_ધો',
        'char_222_ધૌ', 'char_223_ધં', 'char_224_ધઃ', 'char_225_ન', 'char_226_ના','char_227_નિ','char_228_ની', 'char_229_નુ',
        'char_230_નૂ', 'char_231_ને', 'char_232_નૈ', 'char_233_નો',
        'char_234_નૌ', 'char_235_નં', 'char_236_નઃ', 'char_237_પ', 'char_238_પા', 'char_239_પિ', 'char_240_પી','char_241_પુ',
        'char_242_પૂ', 'char_243_પે', 'char_244_પૈ', 'char_245_પો',
        'char_246_પૌ', 'char_247_પં', 'char_248_પઃ','char_249_ફ', 'char_250_ફા','char_251_ફિ', 'char_252_ફી', 'char_253_ફુ', 
        'char_254_ફૂ', 'char_255_ફે', 'char_256_ફૈ', 'char_257_ફો', 'char_258_ફૌ',
        'char_259_ફં', 'char_260_ફઃ', 'char_261_બ', 'char_262_બા', 'char_263_બિ', 'char_264_બી', 'char_265_બુ', 'char_266_બૂ', 
        'char_267_બે', 'char_268_બૈ', 'char_269_બો', 'char_270_બૌ',
        'char_271_બં','char_272_બઃ', 'char_273_ભ', 'char_274_ભા', 'char_275_ભિ', 'char_276_ભી', 'char_277_ભુ', 'char_278_ભૂ',
        'char_279_ભે', 'char_280_ભૈ', 'char_281_ભો', 'char_282_ભૌ',
        'char_283_ભં', 'char_284_ભઃ','char_285_મ', 'char_286_મા', 'char_287_મિ', 'char_288_મી','char_289_મુ','char_290_મૂ',
        'char_291_મે', 'char_292_મૈ', 'char_293_મો', 'char_294_મૌ',
        'char_295_મં', 'char_296_મઃ', 'char_297_ય', 'char_298_યા', 'char_299_યિ', 'char_300_યી', 'char_301_યુ', 'char_302_યૂ',
        'char_303_યે', 'char_304_યૈ', 'char_305_યો', 'char_306_યૌ',
        'char_307_યં', 'char_308_યઃ', 'char_309_ર', 'char_310_રા', 'char_311_રિ', 'char_312_રી', 'char_313_રુ', 'char_314_રૂ',
        'char_315_રે', 'char_316_રૈ', 'char_317_રો', 'char_318_રૌ', 'char_319_રં',
        'char_320_રઃ', 'char_321_લ', 'char_322_લા', 'char_323_લિ', 'char_324_લી', 'char_325_લુ','char_326_લૂ','char_327_લે', 
        'char_328_લૈ', 'char_329_લો', 'char_330_લૌ', 'char_331_લં',
        'char_332_લઃ', 'char_333_વ', 'char_334_વા', 'char_335_વિ', 'char_336_વી', 'char_337_વુ', 'char_338_વૂ', 'char_339_વે',
        'char_340_વૈ', 'char_341_વો', 'char_342_વૌ', 'char_343_વં',
        'char_344_વઃ', 'char_345_શ', 'char_346_શા', 'char_347_શિ', 'char_348_શી', 'char_349_શુ', 'char_350_શૂ', 'char_351_શે',
        'char_352_શૈ', 'char_353_શો', 'char_354_શૌ', 'char_355_શં',
        'char_356_શઃ', 'char_357_ષ', 'char_358_ષા', 'char_359_ષિ', 'char_360_ષી', 'char_361_ષુ', 'char_362_ષૂ','char_363_ષે', 
        'char_364_ષૈ', 'char_365_ષો', 'char_366_ષૌ', 'char_367_ષં', 
        'char_368_ષઃ', 'char_369_સ', 'char_370_સા', 'char_371_સિ', 'char_372_સી', 'char_373_સુ', 'char_374_સૂ', 'char_375_સે',
        'char_376_સૈ', 'char_377_સો', 'char_378_સૌ', 'char_379_સં',
        'char_380_સઃ', 'char_381_હ', 'char_382_હા', 'char_383_હિ', 'char_384_હી', 'char_385_હુ','char_386_હૂ', 'char_387_હે',
        'char_388_હૈ', 'char_389_હો', 'char_390_હૌ', 'char_391_હં',
        'char_392_હઃ', 'char_393_ળ', 'char_394_ળા', 'char_395_ળિ','char_396_ળી', 'char_397_ળુ','char_398_ળૂ','char_399_ળે', 
        'char_400_ળૈ', 'char_401_ળો', 'char_402_ળૌ','char_403_ળં',
        'char_404_ળઃ', 'char_405_ક્ષ', 'char_406_ક્ષા', 'char_407_ક્ષિ', 'char_408_ક્ષી', 'char_409_ક્ષુ', 'char_410_ક્ષૂ', 'char_411_ક્ષે',
        'char_412_ક્ષૈ', 'char_413_ક્ષો', 'char_414_ક્ષૌ',
        'char_415_ક્ષં', 'char_416_ક્ષઃ', 'char_417_જ્ઞ', 'char_418_જ્ઞા', 'char_419_જ્ઞિ', 'char_420_જ્ઞી', 'char_421_જ્ઞુ', 'char_422_જ્ઞૂ',
        'char_423_જ્ઞે', 'char_424_જ્ઞૈ', 'char_425_જ્ઞો', 'char_426_જ્ઞૌ',
        'char_427_જ્ઞં', 'char_428_જ્ઞઃ', 'char_429_કૃ', 'char_430_ઞ', 'char_431_ત્ર', 'char_432_ત્રા', 'char_433_ત્રિ','char_434_ત્રી',
        'char_435_ત્રુ', 'char_436_ત્રૂ', 'char_437_ત્રે', 'char_438_ત્રો','char_439_ત્રૈ',
        'char_440_ત્રૌ', 'char_441_દ્ર', 'char_442_શ્રા', 'char_443_શ્ર', 'char_444_તં', 'char_445_તઃ']#total labels

# %%
test_ratio = 0.25

# %%
for cls in classes_dir:
    os.makedirs(root_dir +'train/' + cls)
    os.makedirs(root_dir +'test/' + cls)
    src = root_dir + cls # Folder to copy images from

    allFileNames = os.listdir(src)
    np.random.shuffle(allFileNames)
    train_FileNames, test_FileNames = np.split(np.array(allFileNames),
                                                          [int(len(allFileNames)* (1 - test_ratio))])


    train_FileNames = [src+'/'+ name for name in train_FileNames.tolist()]
    test_FileNames = [src+'/' + name for name in test_FileNames.tolist()]

    print('Total images: ', len(allFileNames))
    print('Training: ', len(train_FileNames))
    print('Testing: ', len(test_FileNames))

# Copy-pasting images
    
    for name in train_FileNames:
            shutil.copy(name, root_dir +'train/' + cls)

    for name in test_FileNames:
            shutil.copy(name, root_dir +'test/' + cls)
# Out:
# Total images:  60
# Training:  45
# Testing:  15
# Total images:  45
# Training:  33
# Testing:  12
# Total images:  49
# Training:  36
# Testing:  13
# Total images:  48
# Training:  36
# Testing:  12
# Total images:  53
# Training:  39
# Testing:  14
# Total images:  44
# Training:  33
# Testing:  11
# Total images:  45
# Training:  33
# Testing:  12
# Total images:  58
# Training:  43
# Testing:  15
# Total images:  60
# Training:  45
# Testing:  15
# Total images:  56
# Training:  42
# Testing:  14
# Total images:  65
# Training:  48
# Testing:  17
# Total images:  81
# Training:  60
# Testing:  21
# Total images:  88
# Training:  66
# Testing:  22
# Total images:  90
# Training:  67
# Testing:  23
# Total images:  86
# Training:  64
# Testing:  22
# Total images:  72
# Training:  54
# Testing:  18
# Total images:  26
# Training:  19
# Testing:  7
# Total images:  95
# Training:  71
# Testing:  24
# Total images:  85
# Training:  63
# Testing:  22
# Total images:  85
# ...
